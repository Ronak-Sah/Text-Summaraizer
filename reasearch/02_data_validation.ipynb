# %%
# %pwd
# Out:
# 'd:\\Ml Dl\\Project\\Text-Summaraizer\\reasearch'

# %%
cd ../
# Out:
# d:\Ml Dl\Project\Text-Summaraizer
# c:\Users\ronak\anaconda3\envs\text\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %pwd
# Out:
# 'd:\\Ml Dl\\Project\\Text-Summaraizer'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: Path
    status_file : Path
    all_required_files : list

# %%
from src.utils.common import read_yaml
from src.utils.common import create_directories
from src.constants import CONFIG_FILE_PATH,PARAMS_FILE_PATH
class ConfigurationManager:
    def __init__(self,config_filepath= CONFIG_FILE_PATH,params_filepath= PARAMS_FILE_PATH):
        self.config=read_yaml(config_filepath)
        self.params=read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])
    
    def get_data_validation(self) -> DataValidationConfig:
        config = self.config.data_validation                 # Extracts only the data_ingestion part of config.yaml.

        create_directories([config.root_dir])               # Create data_ingestion.root directory

        data_validation_config = DataValidationConfig(
            root_dir=config.root_dir,
            status_file=config.status_file,
            all_required_files=config.all_required_files,
        )

        return data_validation_config

# %%
import os
from src.logger import logger
from src.entity import DataValidationConfig

class Data_Validation:
    def __init__(self,config: DataValidationConfig):
        self.config= config


    def validate_files(self):
        try:
            validation_status= None
            all_files=os.path.join("artifacts","data_ingestion","samsum")

            for file in all_files:
                if file not in self.config.all_required_files:
                    validation_status= False
                    with open(self.config.status_file,"w") as fobj:
                        fobj.write(f"Validation status : {validation_status}")

                else :
                    validation_status = True
                    with open(self.config.status_file,"w") as fobj:
                        fobj.write(f"Validation status : {validation_status}")
            
        except Exception as e:
            logger.error(e)
            raise e
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 5
#       3 from src.logger import logger
#       4 from src.utils.common import get_size
# ----> 5 from src.entity import DataValidationConfig
#       7 class Data_Validation:
#       8     def __init__(self,config: DataValidationConfig):
#
# ImportError: cannot import name 'DataValidationConfig' from 'src.entity' (d:\Ml Dl\Project\Text-Summaraizer\src\entity\__init__.py)
